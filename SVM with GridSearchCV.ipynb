# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
dependent=dataset[['Purchased']]

# %%
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
X_train,X_test,Y_train,Y_test
# Out:
# (     Age  EstimatedSalary  Gender_Male
#  218   46            96000            0
#  101   28            59000            1
#  311   39            96000            1
#  194   28            89000            1
#  326   41            72000            1
#  ..   ...              ...          ...
#  323   48            30000            0
#  192   29            43000            1
#  117   36            52000            1
#  47    27            54000            0
#  172   26           118000            0
#
#  [266 rows x 3 columns],      Age  EstimatedSalary  Gender_Male
#  132   30            87000            1
#  309   38            50000            0
#  341   35            75000            1
#  196   30            79000            0
#  246   35            50000            0
#  ..   ...              ...          ...
#  168   29           148000            1
#  150   26            15000            0
#  393   60            42000            1
#  66    24            19000            1
#  240   42           149000            1
#
#  [134 rows x 3 columns],      Purchased
#  218          0
#  101          0
#  311          1
#  194          0
#  326          0
#  ..         ...
#  323          1
#  192          0
#  117          0
#  47           0
#  172          0
#
#  [266 rows x 1 columns],      Purchased
#  132          0
#  309          0
#  341          0
#  196          0
#  246          0
#  ..         ...
#  168          1
#  150          0
#  393          1
#  66           0
#  240          1
#
#  [134 rows x 1 columns])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
'C':[0.01,0.10,0.100,0.1000,10,100,1000,2000,3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3,cv=5,n_jobs=-1,scoring='f1_weighted')
# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   36.9s finished
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=True, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 0.1, 0.1, 10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

# %%
grid_predictions=grid.predict(X_test)
from sklearn.metrics import confusion_matrix  
cm=confusion_matrix (Y_test,grid_predictions)
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(Y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter{}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter{'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9111247448089108

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[77  8]
#  [ 4 45]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9618247298919568

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.028182      0.007245         0.012592        0.006884    0.01
# 1        0.014790      0.001164         0.003399        0.000489    0.01
# 2        0.024385      0.001356         0.008395        0.005949    0.01
# 3        0.011792      0.002784         0.003998        0.001095    0.01
# 4        0.024585      0.006082         0.005597        0.001853    0.01
# ..            ...           ...              ...             ...     ...
# 67       1.958193      0.375430         0.002798        0.000748    3000
# 68       0.179889      0.034044         0.002599        0.000490    3000
# 69       2.998552      0.609172         0.003399        0.000800    3000
# 70       0.011192      0.000748         0.002399        0.000490    3000
# 71       2.175459      0.232349         0.002999        0.000632    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# ..         ...          ...
# 67        auto       linear
# 68       scale          rbf
# 69       scale         poly
# 70       scale      sigmoid
# 71       scale       linear
#
#                                                params  split0_test_score  \
# 0       {'C': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}           0.509779
# 1      {'C': 0.01, 'gamma': 'auto', 'kernel': 'poly'}           0.623522
# 2   {'C': 0.01, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.509779
# 3    {'C': 0.01, 'gamma': 'auto', 'kernel': 'linear'}           0.699882
# 4      {'C': 0.01, 'gamma': 'scale', 'kernel': 'rbf'}           0.509779
# ..                                                ...                ...
# 67   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 68     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 69    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 70  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 71  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.509779           0.501410           0.501410
# 1            0.576462           0.492321           0.581491
# 2            0.509779           0.501410           0.501410
# 3            0.735616           0.621589           0.818941
# 4            0.509779           0.501410           0.501410
# ..                ...                ...                ...
# 67           0.753889           0.665930           0.943041
# 68           0.869532           0.851527           0.847020
# 69           0.770712           0.766556           0.943699
# 70           0.678162           0.660377           0.777291
# 71           0.753889           0.665930           0.943041
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.516995         0.507855        0.005864               69
# 1            0.559514         0.566940        0.042787               67
# 2            0.516995         0.507855        0.005864               69
# 3            0.783037         0.731515        0.068235               65
# 4            0.516995         0.507855        0.005864               69
# ..                ...              ...             ...              ...
# 67           0.899385         0.807042        0.100426               27
# 68           0.880609         0.854840        0.018809               15
# 69           0.899385         0.839936        0.070331               21
# 70           0.783315         0.741472        0.060379               55
# 71           0.899385         0.807042        0.100426               27
#
# [72 rows x 16 columns]
